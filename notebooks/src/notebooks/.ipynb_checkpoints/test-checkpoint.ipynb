# %%
num=int(input())

# %%
list_num=list(range(1,num+1))

# %%
print(list_num)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
num_max=max(list_num)

# %%
for i in list_num:
    if i< num_max*2:
        list_num.remove(i)

# %%
print(list_num)
# Out:
# [2, 4, 6]
