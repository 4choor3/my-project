# %%
num=int(input())

# %%
list_num=list(range(1,num+1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 list_num=list(range(1,num+1))
#
# NameError: name 'num' is not defined

# %%
print(list_num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(list_num)
#
# NameError: name 'list_num' is not defined

# %%
num_max=max(list_num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 num_max=max(list_num)
#
# NameError: name 'list_num' is not defined

# %%
for i in list_num:
    if i< num_max*2:
        list_num.remove(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 for i in list_num:
#       2     if i< num_max*2:
#       3         list_num.remove(i)
#
# NameError: name 'list_num' is not defined

# %%
print(list_num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(list_num)
#
# NameError: name 'list_num' is not defined
