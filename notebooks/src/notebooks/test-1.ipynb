# %%
num = int(input("请输入一个正整数："))
# Out:
# 运行具有“base (Python 3.13.15)”的单元格需要ipykernel包。
#
# 将“ipykernel”安装到 Python 环境中。
#
# 命令:“conda install -n base ipykernel --update-deps --force-reinstall”

# %%
sum = 1

# %%
for i in range(1,num+1):
    sum *=i

# %%
num_result=max(num**2,sum)

# %%
print(num_result)
